# %% [markdown]
# https://github.com/monologg/KoBERT-nsmc

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/monologg/KoBERT-nsmc.git
# Out:
# fatal: destination path 'KoBERT-nsmc' already exists and is not an empty directory.

# %%
# !pip install transformers
# !pip install sentencepiece

# %%
# %cd KoBERT-nsmc
# Out:
# /content/KoBERT-nsmc

# %%
ls
# Out:
# data/           main.py       README.md           tokenization_kobert.py
# data_loader.py  predict.py    requirements.txt    trainer.py
# LICENSE         __pycache__/  sample_pred_in.txt  utils.py

# %%
# !python main.py --do_train --do_eval
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Iteration:  19% 897/4688 [02:43<11:32,  5.47it/s]
# Iteration:  19% 898/4688 [02:44<11:32,  5.47it/s]
# Iteration:  19% 899/4688 [02:44<11:34,  5.46it/s]
# Iteration:  19% 900/4688 [02:44<11:33,  5.46it/s]
# Iteration:  19% 901/4688 [02:44<11:37,  5.43it/s]
# Iteration:  19% 902/4688 [02:44<11:35,  5.45it/s]
# Iteration:  19% 903/4688 [02:44<11:34,  5.45it/s]
# Iteration:  19% 904/4688 [02:45<11:35,  5.44it/s]
# Iteration:  19% 905/4688 [02:45<11:34,  5.44it/s]
# Iteration:  19% 906/4688 [02:45<11:33,  5.45it/s]
# Iteration:  19% 907/4688 [02:45<11:34,  5.44it/s]
# Iteration:  19% 908/4688 [02:45<11:32,  5.46it/s]
# Iteration:  19% 909/4688 [02:46<11:30,  5.47it/s]
# Iteration:  19% 910/4688 [02:46<11:31,  5.46it/s]
# Iteration:  19% 911/4688 [02:46<11:32,  5.45it/s]
# Iteration:  19% 912/4688 [02:46<11:31,  5.46it/s]
# Iteration:  19% 913/4688 [02:46<11:31,  5.46it/s]
# Iteration:  19% 914/4688 [02:46<11:29,  5.47it/s]
# ...

# %%
cached_file_name = 'cached_{}_{}_{}_{}'.format("nsmc", list(filter(None, "monologg/kobert".split("/"))).pop(), 50, "train")

# %%
cached_file_name
# Out:
# 'cached_nsmc_kobert_50_train'

# %%
import json
import copy

# %%
class InputExample(object):
    """
    A single training/test example for simple sequence classification.

    Args:
        guid: Unique id for the example.
        text_a: string. The untokenized text of the first sequence. For single
        sequence tasks, only this sequence must be specified.
        label: (Optional) string. The label of the example. This should be
        specified for train and dev examples, but not for test examples.
    """

    def __init__(self, guid, text_a, label):
        self.guid = guid
        self.text_a = text_a
        self.label = label

    # 디버깅시 객체를 유의미한 문자열로 출력하는 메소드
    # https://blog.naver.com/websearch/222119748890
    ## __str__(self)는 print(클래스명)을 하면 출력해 줌
    ### 파이썬에서는 str이 없으면 repr를 부르기 때문에 둘 중 하나면 repr를 하는게 좋음
    def __repr__(self):
        return str(self.to_json_string())

    def to_dict(self):
        """Serializes this instance to a Python dictionary."""
        output = copy.deepcopy(self.__dict__)
        return output

    def to_json_string(self):
        """Serializes this instance to a JSON string."""
        return json.dumps(self.to_dict(), indent=2, sort_keys=True) + "\n"

# %%
example = InputExample('tarin-0', '진정한 쓰레기', 0)

# %%
print(example)
# Out:
# {
#   "guid": "tarin-0",
#   "label": 0,
#   "text_a": "\uc9c4\uc815\ud55c \uc4f0\ub808\uae30"
# }
